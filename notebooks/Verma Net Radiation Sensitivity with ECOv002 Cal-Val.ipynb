# %% [markdown]
# # Verma Net Radiation Sensitivity Analysis with ECOv002 Cal-Val
#
# This notebook performs a sensitivity analysis of the Verma net radiation model using ECOSTRESS Collection 2 Cal-Val data. It loads input data, processes it through the Verma net radiation model, and visualizes the impact of input perturbations on latent heat flux. The notebook also generates figures for publication and explores the relationship between surface temperature and latent heat flux.

# %% [markdown]
# ## Import Required Libraries and Functions
#
# This cell imports all necessary libraries and functions for data processing, model execution, statistical analysis, and plotting. It includes custom modules for the BESS-JPL model, sensitivity analysis, and net radiation calculations, as well as standard scientific Python libraries.

# %%
import sys
import os
sys.path.insert(0, os.path.abspath(os.path.join(os.path.dirname("__file__"), '..')))

# %%
from typing import Callable
from os import makedirs
from os.path import join
import numpy as np
import pandas as pd
from verma_net_radiation import verma_net_radiation_table, load_ECOv002_calval_verma_net_radiation_inputs
from monte_carlo_sensitivity import perturbed_run, sensitivity_analysis, divide_absolute_by_unperturbed
import matplotlib.pyplot as plt
from scipy.stats import mstats
import seaborn as sns
from matplotlib.ticker import FuncFormatter

# %% [markdown]
# ## Set Normalization Function
#
# This cell assigns the normalization function used to compare perturbed model outputs to the unperturbed baseline. The function `divide_absolute_by_unperturbed` is used for normalization in the sensitivity analysis.

# %%
normalization_function = divide_absolute_by_unperturbed

# %% [markdown]
# ## Load and Filter Input Data
#
# This cell loads the ECOSTRESS Cal-Val input data using a custom loader function. The resulting DataFrame is displayed for inspection.

# %%
input_df = load_ECOv002_calval_verma_net_radiation_inputs()
input_df
# Out:
#       Unnamed: 0      ID vegetation climate    STICinst   BESSinst  \
# 0              0  US-NC3        ENF     Cfa  270.345200   78.53355
# 1              1  US-Mi3        CVM     Dfb  232.141600  229.20093
# 2              2  US-Mi3        CVM     Dfb  356.355740  335.23154
# 3              3  US-Mi3        CVM     Dfb  332.938400  326.68680
# 4              4  US-Mi3        CVM     Dfb  286.854030  237.21654
# ...          ...     ...        ...     ...         ...        ...
# 1060        1060  US-xAE        GRA     Cfa   70.923310  172.37459
# 1061        1061  US-xAE        GRA     Cfa  116.543190  121.81641
# 1062        1062  US-xAE        GRA     Cfa  129.880100    0.00000
# 1063        1063  US-xAE        GRA     Cfa    2.707851  140.38632
# 1064        1064  US-xAE        GRA     Cfa  303.242950    0.00000
#
#        MOD16inst  PTJPLSMinst      ETinst  ETinstUncertainty  ...  \
# 0     392.851840   307.021970  487.383423         118.916280  ...
# 1     640.118470   375.089300  106.825577         167.919460  ...
# 2     625.661700   284.686250         NaN         132.936340  ...
# 3     624.254330   251.414490  178.827545         141.132420  ...
# 4     511.082180   228.520170  154.791626         114.809410  ...
# ...          ...          ...         ...                ...  ...
# 1060   81.645230    15.282976         NaN          56.385185  ...
# 1061   65.469320    22.186659         NaN          40.509410  ...
# 1062  118.777240    55.343586         NaN          52.403820  ...
# 1063  126.490524    40.434025         NaN          57.769722  ...
# 1064  271.749480   119.763630  190.823303         122.092445  ...
#
#              EndDate  LE_count  closure_ratio                  geometry  \
# 0       1/1/22 05:00      9576           1.02    POINT (-76.656 35.799)
# 1     12/28/19 04:00     12170           0.92   POINT (-80.637 41.8222)
# 2     12/28/19 04:00     12170           0.92   POINT (-80.637 41.8222)
# 3     12/28/19 04:00     12170           0.92   POINT (-80.637 41.8222)
# 4     12/28/19 04:00     12170           0.92   POINT (-80.637 41.8222)
# ...              ...       ...            ...                       ...
# 1060   12/1/22 00:00     29615           0.60  POINT (-99.0588 35.4106)
# 1061   12/1/22 00:00     29615           0.60  POINT (-99.0588 35.4106)
# 1062   12/1/22 00:00     29615           0.60  POINT (-99.0588 35.4106)
# 1063   12/1/22 00:00     29615           0.60  POINT (-99.0588 35.4106)
# 1064   12/1/22 00:00     29615           0.60  POINT (-99.0588 35.4106)
#
#                  time_UTC    ST_K   ST_C       Ta_C   SWin_Wm2  emissivity
# 0     2019-10-02 19:09:40  305.10  31.95  32.658920  545.51056       0.948
# 1     2019-06-23 18:17:17  304.34  31.19  24.227982  848.34390       0.952
# 2     2019-06-27 16:35:42  304.06  30.91  26.178862  838.81160       0.972
# 3     2019-06-30 15:44:10  301.80  28.65  22.527096  851.72480       0.974
# 4     2019-07-01 14:53:48  303.18  30.03  23.280691  702.55160       0.960
# ...                   ...     ...    ...        ...        ...         ...
# 1060  2021-12-11 16:01:12  278.78   5.63   3.815752  286.84660       0.980
# 1061  2022-03-25 22:45:31  293.28  20.13  19.266186  290.87400       0.976
# 1062  2022-04-12 22:53:09  301.94  28.79  32.110336  352.19530       0.976
# 1063  2022-04-14 14:45:37  290.72  17.57  10.464681  420.67880       0.976
# 1064  2022-04-20 19:38:47  314.76  41.61  30.316103  781.84110       0.978
#
# [1065 rows x 77 columns]

# %% [markdown]
# ## Process Input Data Through Model
#
# This cell applies the processing function to the filtered input data, running it through the Verma net radiation and PT-JPL-SM model, and displays the resulting DataFrame.

# %%
processed = verma_net_radiation_table(input_df)
processed
# Out:
# [2025-09-10 10:26:26 INFO] starting Verma net radiation processing
# [2025-09-10 10:26:26 INFO] variable SWout_Wm2 min: 0.000 mean: 66.193 max: 278.058 nan: 0.00% (nan)
# [2025-09-10 10:26:26 INFO] variable SWnet_Wm2 min: 0.000 mean: 540.741 max: 929.140 nan: 0.00% (nan)
# [2025-09-10 10:26:26 INFO] variable LWin_Wm2 min: 175.737 mean: 343.651 max: 473.521 nan: 0.00% (nan)
# [2025-09-10 10:26:26 INFO] variable LWout_Wm2 min: 240.846 mean: 462.295 max: 693.334 nan: 0.00% (nan)
# [2025-09-10 10:26:26 INFO] variable Rn_Wm2 min: 0.000 mean: 422.206 max: 843.390 nan: 0.00% (nan)
# [2025-09-10 10:26:26 INFO] variable Rn_daylight_Wm2 min: 0.000 mean: 257.722 max: 443.569 nan: 0.00% (nan)
# [2025-09-10 10:26:26 INFO] Verma net radiation processing complete in 0.02 seconds
#       Unnamed: 0      ID vegetation climate    STICinst   BESSinst  \
# 0              0  US-NC3        ENF     Cfa  270.345200   78.53355
# 1              1  US-Mi3        CVM     Dfb  232.141600  229.20093
# 2              2  US-Mi3        CVM     Dfb  356.355740  335.23154
# 3              3  US-Mi3        CVM     Dfb  332.938400  326.68680
# 4              4  US-Mi3        CVM     Dfb  286.854030  237.21654
# ...          ...     ...        ...     ...         ...        ...
# 1060        1060  US-xAE        GRA     Cfa   70.923310  172.37459
# 1061        1061  US-xAE        GRA     Cfa  116.543190  121.81641
# 1062        1062  US-xAE        GRA     Cfa  129.880100    0.00000
# 1063        1063  US-xAE        GRA     Cfa    2.707851  140.38632
# 1064        1064  US-xAE        GRA     Cfa  303.242950    0.00000
#
#        MOD16inst  PTJPLSMinst      ETinst  ETinstUncertainty  ...   ST_C  \
# 0     392.851840   307.021970  487.383423         118.916280  ...  31.95
# 1     640.118470   375.089300  106.825577         167.919460  ...  31.19
# 2     625.661700   284.686250         NaN         132.936340  ...  30.91
# 3     624.254330   251.414490  178.827545         141.132420  ...  28.65
# 4     511.082180   228.520170  154.791626         114.809410  ...  30.03
# ...          ...          ...         ...                ...  ...    ...
# 1060   81.645230    15.282976         NaN          56.385185  ...   5.63
# 1061   65.469320    22.186659         NaN          40.509410  ...  20.13
# 1062  118.777240    55.343586         NaN          52.403820  ...  28.79
# 1063  126.490524    40.434025         NaN          57.769722  ...  17.57
# 1064  271.749480   119.763630  190.823303         122.092445  ...  41.61
#
#            Ta_C   SWin_Wm2  emissivity   SWout_Wm2   SWnet_Wm2    LWin_Wm2  \
# 0     32.658920  545.51056       0.948  117.527293  427.983267  433.191382
# 1     24.227982  848.34390       0.952   99.458206  748.885694  355.960473
# 2     26.178862  838.81160       0.972   98.376177  740.435423  385.005187
# 3     22.527096  851.72480       0.974   72.080661  779.644139  357.100788
# 4     23.280691  702.55160       0.960   84.676015  617.875585  358.727378
# ...         ...        ...         ...         ...         ...         ...
# 1060   3.815752  286.84660       0.980   26.634684  260.211916  237.686968
# 1061  19.266186  290.87400       0.976   32.532471  258.341529  317.465236
# 1062  32.110336  352.19530       0.976   37.608161  314.587139  401.910116
# 1063  10.464681  420.67880       0.976   44.918145  375.760655  266.094367
# 1064  30.316103  781.84110       0.978   88.477189  693.363911  393.574271
#
#        LWout_Wm2      Rn_Wm2  Rn_daylight_Wm2
# 0     465.788054  395.386594       236.387027
# 1     463.110120  641.736047       332.853921
# 2     471.101631  654.338979       337.738360
# 3     458.191551  678.553376       366.977454
# 4     459.922447  516.680516       303.069593
# ...          ...         ...              ...
# 1060  335.647726  162.251159       123.775635
# 1061  409.440488  166.366277       178.058285
# 1062  459.984925  256.512330       262.883413
# 1063  395.330786  246.524236       212.287292
# 1064  544.337406  542.600776       285.234441
#
# [1065 rows x 83 columns]

# %% [markdown]
# ## Plot Unperturbed Comparison of Surface Temperature to Latent Heat Flux
#
# This cell creates a scatter plot comparing ECOSTRESS surface temperature to PT-JPL-SM latent heat flux for the unperturbed data. The plot is saved as both JPEG and SVG files for publication or further analysis.

# %%
plt.xticks(range(int(min(processed.ST_C)), int(max(processed.ST_C)) + 1, 5))
plt.scatter(x=processed.ST_C, y=processed.Rn_Wm2, color='black', s=10, zorder=5)
plt.grid(True, zorder=0)
plt.xlabel("ECOSTRESS Surface Temperature (°C)")
plt.ylabel("Verma Net Radiation (W/m$^2$)")
plt.title("Unperturbed Comparison\nof ECOSTRESS Surface Temperature\nto Verma Net Radiation")

plt.savefig("Unperturbed Comparison of ECOSTRESS Surface Temperature to Verma Net Radiation.jpeg", format='jpeg', bbox_inches='tight')
plt.savefig("Unperturbed Comparison of ECOSTRESS Surface Temperature to Verma Net Radiation.svg", format='svg', bbox_inches='tight')

plt.show()

# %% [markdown]
# ## Further Filter Input Data and Check Temperature Range
#
# This cell applies additional filters to the input data, ensuring only valid `fAPARmax` and `NDVI` values are included. It also checks the minimum and maximum surface temperature values in the filtered dataset.

# %%
# input_df = pd.read_csv(input_filename)
input_df = load_ECOv002_calval_verma_net_radiation_inputs()

if "Ta" in input_df and "Ta_C" not in input_df:
    # input_df.rename({"Ta": "Ta_C"}, inplace=True)
    input_df["Ta_C"] = input_df["Ta"]

input_df = input_df[input_df.NDVI.apply(lambda NDVI: NDVI > 0.05)]

np.nanmin(input_df.ST_C), np.nanmax(input_df.ST_C)
# Out:
# (np.float64(-13.189999999999998), np.float64(86.11000000000001))

# %% [markdown]
# ## Check Number of Valid Input Rows
#
# This cell displays the number of rows remaining in the input DataFrame after all filtering steps, confirming the size of the dataset used for analysis.

# %%
len(input_df)
# Out:
# 1063

# %% [markdown]
# ## Run Perturbed Model Analysis
#
# This cell sets up the input and output variables for the sensitivity analysis and runs the `perturbed_run` function, which perturbs the input variable and observes the effect on the output variable using the PT-JPL-SM model. The results are displayed for further analysis.

# %%
input_variable = "ST_C"
output_variable = "Rn_Wm2"

results = perturbed_run(
    input_df=input_df, 
    input_variable=input_variable, 
    output_variable=output_variable, 
    forward_process=verma_net_radiation_table,
    normalization_function=normalization_function
)

results
# Out:
# [2025-09-10 10:27:39 INFO] tarting Monte Carlo perturbed run
# [2025-09-10 10:27:39 INFO] calculating standard deviation of input variable: ST_C
# [2025-09-10 10:27:39 INFO] input variable ST_C standard deviation: 12.285657205245933
# [2025-09-10 10:27:39 INFO] starting forward process
# [2025-09-10 10:27:39 INFO] starting Verma net radiation processing
# [2025-09-10 10:27:39 INFO] variable SWout_Wm2 min: 0.000 mean: 65.951 max: 278.058 nan: 0.00% (nan)
# [2025-09-10 10:27:39 INFO] variable SWnet_Wm2 min: 0.000 mean: 541.474 max: 929.140 nan: 0.00% (nan)
# [2025-09-10 10:27:39 INFO] variable LWin_Wm2 min: 175.737 mean: 343.933 max: 473.521 nan: 0.00% (nan)
# [2025-09-10 10:27:39 INFO] variable LWout_Wm2 min: 248.604 mean: 462.692 max: 693.334 nan: 0.00% (nan)
# [2025-09-10 10:27:39 INFO] variable Rn_Wm2 min: 0.000 mean: 422.824 max: 843.390 nan: 0.00% (nan)
# [2025-09-10 10:27:39 INFO] variable Rn_daylight_Wm2 min: 0.000 mean: 258.106 max: 443.569 nan: 0.00% (nan)
# [2025-09-10 10:27:39 INFO] Verma net radiation processing complete in 0.02 seconds
# [2025-09-10 10:27:39 INFO] forward process completed
# [2025-09-10 10:27:39 INFO] calculating standard deviation of output variable: Rn_Wm2
# [2025-09-10 10:27:39 INFO] output variable Rn_Wm2 standard deviation: 149.08451152972577
# [2025-09-10 10:27:39 INFO] starting input perturbation generation
# [2025-09-10 10:27:39 INFO] input perturbation generation completed
# [2025-09-10 10:27:39 INFO] generating control group
# [2025-09-10 10:27:39 INFO] normalizing input perturbations
# [2025-09-10 10:27:39 INFO] applying perturbations
# [2025-09-10 10:27:39 INFO] starting forward process for perturbed input
# [2025-09-10 10:27:40 INFO] starting Verma net radiation processing
# [2025-09-10 10:27:40 INFO] variable SWout_Wm2 min: 0.000 mean: 65.951 max: 278.058 nan: 0.00% (nan)
# [2025-09-10 10:27:40 INFO] variable SWnet_Wm2 min: 0.000 mean: 541.474 max: 929.140 nan: 0.00% (nan)
# [2025-09-10 10:27:40 INFO] variable LWin_Wm2 min: 175.737 mean: 343.933 max: 473.521 nan: 0.00% (nan)
# [2025-09-10 10:27:40 INFO] variable LWout_Wm2 min: 155.585 mean: 466.880 max: 1050.983 nan: 0.00% (nan)
# [2025-09-10 10:27:40 INFO] variable Rn_Wm2 min: 0.000 mean: 418.854 max: 1015.180 nan: 0.00% (nan)
# [2025-09-10 10:27:42 INFO] variable Rn_daylight_Wm2 min: 0.000 mean: 255.543 max: 533.919 nan: 0.00% (nan)
# [2025-09-10 10:27:42 INFO] Verma net radiation processing complete in 1.28 seconds
# [2025-09-10 10:27:42 INFO] completed forward process for perturbed input
# [2025-09-10 10:27:42 INFO] normalizing output perturbations
# [2025-09-10 10:27:42 INFO] Monte Carlo run complete
#        input_variable output_variable input_unperturbed  input_perturbation  \
# 0                ST_C          Rn_Wm2             31.95            6.151299
# 1                ST_C          Rn_Wm2             31.95          -14.331779
# 2                ST_C          Rn_Wm2             31.95            2.467549
# 3                ST_C          Rn_Wm2             31.95            5.971334
# 4                ST_C          Rn_Wm2             31.95           12.271033
# ...               ...             ...               ...                 ...
# 106295           ST_C          Rn_Wm2             41.61           19.863174
# 106296           ST_C          Rn_Wm2             41.61            8.386470
# 106297           ST_C          Rn_Wm2             41.61          -22.021610
# 106298           ST_C          Rn_Wm2             41.61          -15.734102
# 106299           ST_C          Rn_Wm2             41.61            2.531559
#
#         input_perturbation_std input_perturbed output_unperturbed  \
# 0                     0.192529       38.101299         395.386594
# 1                     0.448569       17.618221         395.386594
# 2                     0.077232       34.417549         395.386594
# 3                     0.186896       37.921334         395.386594
# 4                     0.384070       44.221033         395.386594
# ...                        ...             ...                ...
# 106295                0.477365       61.473174         542.600776
# 106296                0.201549        49.99647         542.600776
# 106297                0.529238        19.58839         542.600776
# 106298                0.378133       25.875898         542.600776
# 106299                0.060840       44.141559         542.600776
#
#        output_perturbation output_perturbation_std output_perturbed
# 0               -38.715472                0.097918       356.671122
# 1                81.543898                0.206238       476.930492
# 2               -15.252361                0.038576       380.134234
# 3               -37.549674                 0.09497        357.83692
# 4               -79.578695                0.201268       315.807899
# ...                    ...                     ...              ...
# 106295         -150.965572                0.278226       391.635204
# 106296          -60.373357                0.111267       482.227419
# 106297          137.080224                0.252636          679.681
# 106298           100.94807                0.186045       643.548847
# 106299           -17.72444                0.032666       524.876336
#
# [105900 rows x 10 columns]

# %% [markdown]
# ## Filter Out NaN Results
#
# This cell removes any rows with missing values from the perturbed results to ensure only valid data points are used in subsequent analysis and plotting.

# %%
filtered_results = results.dropna()
filtered_results
# Out:
#        input_variable output_variable input_unperturbed  input_perturbation  \
# 0                ST_C          Rn_Wm2             31.95            6.151299
# 1                ST_C          Rn_Wm2             31.95          -14.331779
# 2                ST_C          Rn_Wm2             31.95            2.467549
# 3                ST_C          Rn_Wm2             31.95            5.971334
# 4                ST_C          Rn_Wm2             31.95           12.271033
# ...               ...             ...               ...                 ...
# 106295           ST_C          Rn_Wm2             41.61           19.863174
# 106296           ST_C          Rn_Wm2             41.61            8.386470
# 106297           ST_C          Rn_Wm2             41.61          -22.021610
# 106298           ST_C          Rn_Wm2             41.61          -15.734102
# 106299           ST_C          Rn_Wm2             41.61            2.531559
#
#         input_perturbation_std input_perturbed output_unperturbed  \
# 0                     0.192529       38.101299         395.386594
# 1                     0.448569       17.618221         395.386594
# 2                     0.077232       34.417549         395.386594
# 3                     0.186896       37.921334         395.386594
# 4                     0.384070       44.221033         395.386594
# ...                        ...             ...                ...
# 106295                0.477365       61.473174         542.600776
# 106296                0.201549        49.99647         542.600776
# 106297                0.529238        19.58839         542.600776
# 106298                0.378133       25.875898         542.600776
# 106299                0.060840       44.141559         542.600776
#
#        output_perturbation output_perturbation_std output_perturbed
# 0               -38.715472                0.097918       356.671122
# 1                81.543898                0.206238       476.930492
# 2               -15.252361                0.038576       380.134234
# 3               -37.549674                 0.09497        357.83692
# 4               -79.578695                0.201268       315.807899
# ...                    ...                     ...              ...
# 106295         -150.965572                0.278226       391.635204
# 106296          -60.373357                0.111267       482.227419
# 106297          137.080224                0.252636          679.681
# 106298           100.94807                0.186045       643.548847
# 106299           -17.72444                0.032666       524.876336
#
# [105900 rows x 10 columns]

# %% [markdown]
# ## Plot Change in Surface Temperature vs Net Radiation
#
# This cell generates a scatter plot showing the relationship between changes in surface temperature and changes in Verma net radiation due to input perturbations. The plot is saved as JPEG and SVG files.

# %%
# plt.xticks(range(int(min(processed.ST_C)), int(max(processed.ST_C)) + 1, 5))
# plt.ylim(-350, 150)
plt.scatter(x=results.input_perturbation, y=results.output_perturbation, color='black', s=10, zorder=5)  # Adjust the 's' parameter to make dots thinner
plt.grid(True, zorder=0)
plt.xlabel("Change in Surface Temperature (°C)")
plt.ylabel("Change in Verma Net Radiation (W/m$^2$)")
plt.title("Comparison of Change\nin Surface Temperature\nto Verma Net Radiation")

plt.savefig("Comparison of Change in Surface Temperature to Verma Net Radiation.jpeg", format='jpeg', bbox_inches='tight')
plt.savefig("Comparison of Change in Surface Temperature to Verma Net Radiation.svg", format='svg', bbox_inches='tight')

plt.show()

# %%
sc = plt.scatter(
    x=results.input_perturbation, 
    y=results.output_perturbation, 
    c=results.input_unperturbed, 
    color=None,
    cmap="jet",
    s=10, 
    zorder=5
)

plt.grid(True, zorder=0)
plt.xlabel("Change in Surface Temperature (°C)")
plt.ylabel("Change in Verma Net Radiation (W/m$^2$)")
plt.title("Comparison of Change\nin Surface Temperature\nto Verma Net Radiation", pad=20)
plt.colorbar(sc, label="ECOSTRESS Surface Temperature (°C)")
plt.savefig("Comparison of Change in Surface Temperature to Verma Net Radiation.jpeg", format='jpeg', bbox_inches='tight')
plt.savefig("Comparison of Change in Surface Temperature to Verma Net Radiation.svg", format='svg', bbox_inches='tight')

plt.show()

# %% [markdown]
# ## Compute Correlation Between Input and Output Perturbations
#
# This cell calculates the Pearson correlation coefficient between the standardized input and output perturbations, quantifying the strength of their linear relationship.

# %%
correlation = mstats.pearsonr(
    np.array(filtered_results.input_perturbation_std).astype(np.float64), 
    np.array(filtered_results.output_perturbation_std).astype(np.float64)
)[0]

correlation
# Out:
# np.float64(0.018194717692561063)

# %% [markdown]
# ## Run Full Sensitivity Analysis for Multiple Inputs
#
# This cell performs a comprehensive sensitivity analysis by perturbing several input variables (surface temperature, NDVI, albedo, air temperature, relative humidity) and measuring their effect on latent heat flux. The results are summarized in a DataFrame.

# %%
input_variables = ["ST_C", "NDVI", "albedo", "Ta_C", "RH"]
output_variables = ["Rn_Wm2"]

perturbation_df, sensitivity_metrics_df = sensitivity_analysis(
    input_df=input_df,
    input_variables=input_variables,
    output_variables=output_variables,
    forward_process=verma_net_radiation_table,
    normalization_function=normalization_function
)

sensitivity_metrics_df
# Out:
# [2025-09-10 10:29:17 INFO] tarting Monte Carlo perturbed run
# [2025-09-10 10:29:17 INFO] calculating standard deviation of input variable: ST_C
# [2025-09-10 10:29:17 INFO] input variable ST_C standard deviation: 12.285657205245933
# [2025-09-10 10:29:17 INFO] starting forward process
# [2025-09-10 10:29:17 INFO] starting Verma net radiation processing
# [2025-09-10 10:29:17 INFO] variable SWout_Wm2 min: 0.000 mean: 65.951 max: 278.058 nan: 0.00% (nan)
# [2025-09-10 10:29:17 INFO] variable SWnet_Wm2 min: 0.000 mean: 541.474 max: 929.140 nan: 0.00% (nan)
# [2025-09-10 10:29:17 INFO] variable LWin_Wm2 min: 175.737 mean: 343.933 max: 473.521 nan: 0.00% (nan)
# [2025-09-10 10:29:17 INFO] variable LWout_Wm2 min: 248.604 mean: 462.692 max: 693.334 nan: 0.00% (nan)
# [2025-09-10 10:29:17 INFO] variable Rn_Wm2 min: 0.000 mean: 422.824 max: 843.390 nan: 0.00% (nan)
# [2025-09-10 10:29:17 INFO] variable Rn_daylight_Wm2 min: 0.000 mean: 258.106 max: 443.569 nan: 0.00% (nan)
# [2025-09-10 10:29:17 INFO] Verma net radiation processing complete in 0.02 seconds
# [2025-09-10 10:29:17 INFO] forward process completed
# [2025-09-10 10:29:17 INFO] calculating standard deviation of output variable: Rn_Wm2
# [2025-09-10 10:29:17 INFO] output variable Rn_Wm2 standard deviation: 149.08451152972577
# [2025-09-10 10:29:17 INFO] starting input perturbation generation
# [2025-09-10 10:29:17 INFO] input perturbation generation completed
# [2025-09-10 10:29:17 INFO] generating control group
# [2025-09-10 10:29:17 INFO] normalizing input perturbations
# [2025-09-10 10:29:17 INFO] applying perturbations
# [2025-09-10 10:29:17 INFO] starting forward process for perturbed input
# [2025-09-10 10:29:18 INFO] starting Verma net radiation processing
# [2025-09-10 10:29:18 INFO] variable SWout_Wm2 min: 0.000 mean: 65.951 max: 278.058 nan: 0.00% (nan)
# [2025-09-10 10:29:18 INFO] variable SWnet_Wm2 min: 0.000 mean: 541.474 max: 929.140 nan: 0.00% (nan)
# [2025-09-10 10:29:18 INFO] variable LWin_Wm2 min: 175.737 mean: 343.933 max: 473.521 nan: 0.00% (nan)
# [2025-09-10 10:29:18 INFO] variable LWout_Wm2 min: 140.192 mean: 467.216 max: 1032.961 nan: 0.00% (nan)
# [2025-09-10 10:29:18 INFO] variable Rn_Wm2 min: 0.000 mean: 418.509 max: 977.599 nan: 0.00% (nan)
# [2025-09-10 10:29:19 INFO] variable Rn_daylight_Wm2 min: 0.000 mean: 255.380 max: 541.401 nan: 0.00% (nan)
# [2025-09-10 10:29:19 INFO] Verma net radiation processing complete in 1.27 seconds
# [2025-09-10 10:29:20 INFO] completed forward process for perturbed input
# [2025-09-10 10:29:20 INFO] normalizing output perturbations
# [2025-09-10 10:29:20 INFO] Monte Carlo run complete
# [2025-09-10 10:29:20 INFO] tarting Monte Carlo perturbed run
# [2025-09-10 10:29:20 INFO] calculating standard deviation of input variable: NDVI
# [2025-09-10 10:29:20 INFO] input variable NDVI standard deviation: 0.24919504831147038
# [2025-09-10 10:29:20 INFO] starting forward process
# [2025-09-10 10:29:20 INFO] starting Verma net radiation processing
# [2025-09-10 10:29:20 INFO] variable SWout_Wm2 min: 0.000 mean: 65.951 max: 278.058 nan: 0.00% (nan)
# [2025-09-10 10:29:20 INFO] variable SWnet_Wm2 min: 0.000 mean: 541.474 max: 929.140 nan: 0.00% (nan)
# [2025-09-10 10:29:20 INFO] variable LWin_Wm2 min: 175.737 mean: 343.933 max: 473.521 nan: 0.00% (nan)
# [2025-09-10 10:29:20 INFO] variable LWout_Wm2 min: 248.604 mean: 462.692 max: 693.334 nan: 0.00% (nan)
# [2025-09-10 10:29:20 INFO] variable Rn_Wm2 min: 0.000 mean: 422.824 max: 843.390 nan: 0.00% (nan)
# [2025-09-10 10:29:20 INFO] variable Rn_daylight_Wm2 min: 0.000 mean: 258.106 max: 443.569 nan: 0.00% (nan)
# [2025-09-10 10:29:20 INFO] Verma net radiation processing complete in 0.02 seconds
# [2025-09-10 10:29:20 INFO] forward process completed
# [2025-09-10 10:29:20 INFO] calculating standard deviation of output variable: Rn_Wm2
# [2025-09-10 10:29:20 INFO] output variable Rn_Wm2 standard deviation: 149.08451152972577
# [2025-09-10 10:29:20 INFO] starting input perturbation generation
# [2025-09-10 10:29:20 INFO] input perturbation generation completed
# [2025-09-10 10:29:20 INFO] generating control group
# [2025-09-10 10:29:20 INFO] normalizing input perturbations
# [2025-09-10 10:29:20 INFO] applying perturbations
# [2025-09-10 10:29:20 INFO] starting forward process for perturbed input
# /opt/homebrew/Caskroom/miniforge/base/envs/verma-net-radiation/lib/python3.10/site-packages/monte_carlo_sensitivity/sensitivity_analysis.py:77: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   perturbation_df = pd.concat([perturbation_df, run_results])
# /opt/homebrew/Caskroom/miniforge/base/envs/verma-net-radiation/lib/python3.10/site-packages/monte_carlo_sensitivity/sensitivity_analysis.py:89: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   sensitivity_metrics_df = pd.concat([sensitivity_metrics_df, pd.DataFrame([[
# [2025-09-10 10:29:21 INFO] starting Verma net radiation processing
# [2025-09-10 10:29:21 INFO] variable SWout_Wm2 min: 0.000 mean: 65.951 max: 278.058 nan: 0.00% (nan)
# [2025-09-10 10:29:21 INFO] variable SWnet_Wm2 min: 0.000 mean: 541.474 max: 929.140 nan: 0.00% (nan)
# [2025-09-10 10:29:21 INFO] variable LWin_Wm2 min: 175.737 mean: 343.933 max: 473.521 nan: 0.00% (nan)
# [2025-09-10 10:29:21 INFO] variable LWout_Wm2 min: 248.604 mean: 462.692 max: 693.334 nan: 0.00% (nan)
# [2025-09-10 10:29:21 INFO] variable Rn_Wm2 min: 0.000 mean: 422.824 max: 843.390 nan: 0.00% (nan)
# [2025-09-10 10:29:22 INFO] variable Rn_daylight_Wm2 min: 0.000 mean: 258.106 max: 443.569 nan: 0.00% (nan)
# [2025-09-10 10:29:22 INFO] Verma net radiation processing complete in 1.22 seconds
# [2025-09-10 10:29:22 INFO] completed forward process for perturbed input
# [2025-09-10 10:29:22 INFO] normalizing output perturbations
# [2025-09-10 10:29:22 INFO] Monte Carlo run complete
# [2025-09-10 10:29:22 INFO] tarting Monte Carlo perturbed run
# [2025-09-10 10:29:22 INFO] calculating standard deviation of input variable: albedo
# [2025-09-10 10:29:22 INFO] input variable albedo standard deviation: 0.05366279984322165
# [2025-09-10 10:29:22 INFO] starting forward process
# [2025-09-10 10:29:22 INFO] starting Verma net radiation processing
# [2025-09-10 10:29:22 INFO] variable SWout_Wm2 min: 0.000 mean: 65.951 max: 278.058 nan: 0.00% (nan)
# [2025-09-10 10:29:22 INFO] variable SWnet_Wm2 min: 0.000 mean: 541.474 max: 929.140 nan: 0.00% (nan)
# [2025-09-10 10:29:22 INFO] variable LWin_Wm2 min: 175.737 mean: 343.933 max: 473.521 nan: 0.00% (nan)
# [2025-09-10 10:29:22 INFO] variable LWout_Wm2 min: 248.604 mean: 462.692 max: 693.334 nan: 0.00% (nan)
# [2025-09-10 10:29:22 INFO] variable Rn_Wm2 min: 0.000 mean: 422.824 max: 843.390 nan: 0.00% (nan)
# [2025-09-10 10:29:22 INFO] variable Rn_daylight_Wm2 min: 0.000 mean: 258.106 max: 443.569 nan: 0.00% (nan)
# [2025-09-10 10:29:22 INFO] Verma net radiation processing complete in 0.02 seconds
# [2025-09-10 10:29:22 INFO] forward process completed
# [2025-09-10 10:29:22 INFO] calculating standard deviation of output variable: Rn_Wm2
# [2025-09-10 10:29:22 INFO] output variable Rn_Wm2 standard deviation: 149.08451152972577
# [2025-09-10 10:29:22 INFO] starting input perturbation generation
# [2025-09-10 10:29:22 INFO] input perturbation generation completed
# [2025-09-10 10:29:22 INFO] generating control group
# [2025-09-10 10:29:22 INFO] normalizing input perturbations
# [2025-09-10 10:29:22 INFO] applying perturbations
# [2025-09-10 10:29:22 INFO] starting forward process for perturbed input
# /opt/homebrew/Caskroom/miniforge/base/envs/verma-net-radiation/lib/python3.10/site-packages/scipy/stats/_mstats_basic.py:570: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return scipy.stats._stats_py.pearsonr(
# [2025-09-10 10:29:23 INFO] starting Verma net radiation processing
# [2025-09-10 10:29:23 INFO] variable SWout_Wm2 min: 0.000 mean: 66.690 max: 384.654 nan: 0.00% (nan)
# [2025-09-10 10:29:23 INFO] variable SWnet_Wm2 min: 0.000 mean: 540.736 max: 1032.841 nan: 0.00% (nan)
# [2025-09-10 10:29:23 INFO] variable LWin_Wm2 min: 175.737 mean: 343.933 max: 473.521 nan: 0.00% (nan)
# [2025-09-10 10:29:23 INFO] variable LWout_Wm2 min: 248.604 mean: 462.692 max: 693.334 nan: 0.00% (nan)
# [2025-09-10 10:29:23 INFO] variable Rn_Wm2 min: 0.000 mean: 422.093 max: 947.091 nan: 0.00% (nan)
# [2025-09-10 10:29:25 INFO] variable Rn_daylight_Wm2 min: 0.000 mean: 257.655 max: 498.109 nan: 0.00% (nan)
# [2025-09-10 10:29:25 INFO] Verma net radiation processing complete in 1.26 seconds
# [2025-09-10 10:29:25 INFO] completed forward process for perturbed input
# [2025-09-10 10:29:25 INFO] normalizing output perturbations
# [2025-09-10 10:29:25 INFO] Monte Carlo run complete
# [2025-09-10 10:29:25 INFO] tarting Monte Carlo perturbed run
# [2025-09-10 10:29:25 INFO] calculating standard deviation of input variable: Ta_C
# [2025-09-10 10:29:25 INFO] input variable Ta_C standard deviation: 8.298861169388706
# [2025-09-10 10:29:25 INFO] starting forward process
# [2025-09-10 10:29:25 INFO] starting Verma net radiation processing
# [2025-09-10 10:29:25 INFO] variable SWout_Wm2 min: 0.000 mean: 65.951 max: 278.058 nan: 0.00% (nan)
# [2025-09-10 10:29:25 INFO] variable SWnet_Wm2 min: 0.000 mean: 541.474 max: 929.140 nan: 0.00% (nan)
# [2025-09-10 10:29:25 INFO] variable LWin_Wm2 min: 175.737 mean: 343.933 max: 473.521 nan: 0.00% (nan)
# [2025-09-10 10:29:25 INFO] variable LWout_Wm2 min: 248.604 mean: 462.692 max: 693.334 nan: 0.00% (nan)
# [2025-09-10 10:29:25 INFO] variable Rn_Wm2 min: 0.000 mean: 422.824 max: 843.390 nan: 0.00% (nan)
# [2025-09-10 10:29:25 INFO] variable Rn_daylight_Wm2 min: 0.000 mean: 258.106 max: 443.569 nan: 0.00% (nan)
# [2025-09-10 10:29:25 INFO] Verma net radiation processing complete in 0.02 seconds
# [2025-09-10 10:29:25 INFO] forward process completed
# [2025-09-10 10:29:25 INFO] calculating standard deviation of output variable: Rn_Wm2
# [2025-09-10 10:29:25 INFO] output variable Rn_Wm2 standard deviation: 149.08451152972577
# [2025-09-10 10:29:25 INFO] starting input perturbation generation
# [2025-09-10 10:29:25 INFO] input perturbation generation completed
# [2025-09-10 10:29:25 INFO] generating control group
# [2025-09-10 10:29:25 INFO] normalizing input perturbations
# [2025-09-10 10:29:25 INFO] applying perturbations
# [2025-09-10 10:29:25 INFO] starting forward process for perturbed input
# [2025-09-10 10:29:26 INFO] starting Verma net radiation processing
# [2025-09-10 10:29:26 INFO] variable SWout_Wm2 min: 0.000 mean: 65.951 max: 278.058 nan: 0.00% (nan)
# [2025-09-10 10:29:26 INFO] variable SWnet_Wm2 min: 0.000 mean: 541.474 max: 929.140 nan: 0.00% (nan)
# [2025-09-10 10:29:26 INFO] variable LWin_Wm2 min: 128.103 mean: 348.693 max: 712.607 nan: 0.00% (nan)
# [2025-09-10 10:29:26 INFO] variable LWout_Wm2 min: 248.604 mean: 462.692 max: 693.334 nan: 0.00% (nan)
# [2025-09-10 10:29:26 INFO] variable Rn_Wm2 min: 0.000 mean: 427.663 max: 1063.394 nan: 0.00% (nan)
# [2025-09-10 10:29:27 INFO] variable Rn_daylight_Wm2 min: 0.000 mean: 261.284 max: 589.515 nan: 0.00% (nan)
# [2025-09-10 10:29:27 INFO] Verma net radiation processing complete in 1.28 seconds
# [2025-09-10 10:29:27 INFO] completed forward process for perturbed input
# [2025-09-10 10:29:27 INFO] normalizing output perturbations
# [2025-09-10 10:29:27 INFO] Monte Carlo run complete
# [2025-09-10 10:29:27 INFO] tarting Monte Carlo perturbed run
# [2025-09-10 10:29:27 INFO] calculating standard deviation of input variable: RH
# [2025-09-10 10:29:27 INFO] input variable RH standard deviation: 0.12004046934391559
# [2025-09-10 10:29:27 INFO] starting forward process
# [2025-09-10 10:29:27 INFO] starting Verma net radiation processing
# [2025-09-10 10:29:27 INFO] variable SWout_Wm2 min: 0.000 mean: 65.951 max: 278.058 nan: 0.00% (nan)
# [2025-09-10 10:29:27 INFO] variable SWnet_Wm2 min: 0.000 mean: 541.474 max: 929.140 nan: 0.00% (nan)
# [2025-09-10 10:29:27 INFO] variable LWin_Wm2 min: 175.737 mean: 343.933 max: 473.521 nan: 0.00% (nan)
# [2025-09-10 10:29:27 INFO] variable LWout_Wm2 min: 248.604 mean: 462.692 max: 693.334 nan: 0.00% (nan)
# [2025-09-10 10:29:27 INFO] variable Rn_Wm2 min: 0.000 mean: 422.824 max: 843.390 nan: 0.00% (nan)
# [2025-09-10 10:29:27 INFO] variable Rn_daylight_Wm2 min: 0.000 mean: 258.106 max: 443.569 nan: 0.00% (nan)
# [2025-09-10 10:29:27 INFO] Verma net radiation processing complete in 0.02 seconds
# [2025-09-10 10:29:27 INFO] forward process completed
# [2025-09-10 10:29:27 INFO] calculating standard deviation of output variable: Rn_Wm2
# [2025-09-10 10:29:27 INFO] output variable Rn_Wm2 standard deviation: 149.08451152972577
# [2025-09-10 10:29:27 INFO] starting input perturbation generation
# [2025-09-10 10:29:27 INFO] input perturbation generation completed
# [2025-09-10 10:29:27 INFO] generating control group
# [2025-09-10 10:29:27 INFO] normalizing input perturbations
# [2025-09-10 10:29:27 INFO] applying perturbations
# [2025-09-10 10:29:27 INFO] starting forward process for perturbed input
# [2025-09-10 10:29:28 INFO] starting Verma net radiation processing
# [2025-09-10 10:29:29 INFO] variable SWout_Wm2 min: 0.000 mean: 65.951 max: 278.058 nan: 0.00% (nan)
# [2025-09-10 10:29:29 INFO] variable SWnet_Wm2 min: 0.000 mean: 541.474 max: 929.140 nan: 0.00% (nan)
# [2025-09-10 10:29:29 INFO] variable LWin_Wm2 min: 173.558 mean: 342.982 max: 506.734 nan: 0.00% (nan)
# [2025-09-10 10:29:29 INFO] variable LWout_Wm2 min: 248.604 mean: 462.692 max: 693.334 nan: 0.00% (nan)
# [2025-09-10 10:29:29 INFO] variable Rn_Wm2 min: 0.000 mean: 421.805 max: 864.125 nan: 0.00% (nan)
# [2025-09-10 10:29:30 INFO] variable Rn_daylight_Wm2 min: 0.000 mean: 257.468 max: 454.474 nan: 0.00% (nan)
# [2025-09-10 10:29:30 INFO] Verma net radiation processing complete in 1.25 seconds
# [2025-09-10 10:29:30 INFO] completed forward process for perturbed input
# [2025-09-10 10:29:30 INFO] normalizing output perturbations
# [2025-09-10 10:29:30 INFO] Monte Carlo run complete
#   input_variable output_variable                  metric     value
# 0           ST_C          Rn_Wm2             correlation  0.021785
# 0           ST_C          Rn_Wm2                      r2  0.000475
# 0           ST_C          Rn_Wm2  mean_normalized_change  0.177903
# 0           NDVI          Rn_Wm2             correlation       NaN
# 0           NDVI          Rn_Wm2                      r2  0.000000
# 0           NDVI          Rn_Wm2  mean_normalized_change  0.000000
# 0         albedo          Rn_Wm2             correlation  0.287367
# 0         albedo          Rn_Wm2                      r2  0.082580
# 0         albedo          Rn_Wm2  mean_normalized_change  0.063450
# 0           Ta_C          Rn_Wm2             correlation  0.011142
# 0           Ta_C          Rn_Wm2                      r2  0.000124
# 0           Ta_C          Rn_Wm2  mean_normalized_change  0.136480
# 0             RH          Rn_Wm2             correlation  0.130603
# 0             RH          Rn_Wm2                      r2  0.017057
# 0             RH          Rn_Wm2  mean_normalized_change  0.027115

# %% [markdown]
# ## Plot Sensitivity Magnitude Bar Chart
#
# This cell creates a bar chart showing the average percent change in latent heat flux for each input variable, visualizing the magnitude of model sensitivity to each input. The plot is saved as JPEG and SVG files with the BESS-JPL label.

# %%
df = sensitivity_metrics_df
df = df[(df.output_variable == "LE_Wm2") & (df.metric == "mean_normalized_change")]
ax = sns.barplot(x=df.input_variable, y=df.value * 100, color='black')
ax.set_xticklabels(["Surface\nTemperature", "NDVI", "Albedo", "Air\nTemperature", "Relative\nHumidity"])
plt.xlabel("Input Variable")
plt.ylabel("Average Percent Change in Output Perturbation")
plt.title("BESS-JPL Latent Heat Flux Sensitivity Magnitude")
# plt.ylim(0, 160)  # Set y-axis range from 0 to 160
plt.grid(axis='y', color='lightgray', linestyle='-', linewidth=0.5)  # Add light gray horizontal gridlines only

# Add percent sign to y-axis tick labels
ax.yaxis.set_major_formatter(FuncFormatter(lambda y, _: f'{int(y)}%'))

plt.savefig("BESS-JPL Latent Heat Flux Sensitivity Magnitude.jpeg", format='jpeg', bbox_inches='tight')
plt.savefig("BESS-JPL Latent Heat Flux Sensitivity Magnitude.svg", format='svg', bbox_inches='tight')

plt.show()
# Out:
# /var/folders/hk/35_x93nx79vg1zmd2fy1vcbr0000gq/T/ipykernel_35969/3108202059.py:4: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(["Surface\nTemperature", "NDVI", "Albedo", "Air\nTemperature", "Relative\nHumidity"])

# %% [markdown]
# ## Plot Sensitivity Correlation Bar Chart
#
# This cell generates a bar chart showing the correlation between input perturbations and output perturbations for each input variable, highlighting which inputs most strongly influence latent heat flux. The plot is saved as JPEG and SVG files with the PT-JPL-SM label.

# %%
df = sensitivity_metrics_df
df = df[(df.output_variable == "Rn_Wm2") & (df.metric == "correlation")]
ax = sns.barplot(x=df.input_variable, y=df.value, color='black')
ax.set_xticklabels(["Surface\nTemperature", "NDVI", "Albedo", "Air\nTemperature", "Relative\nHumidity"])
# plt.ylim(0, 0.8)
plt.xlabel("Input Variable")
plt.ylabel("Correlation of Input Perturbation to Output Perturbation")
plt.title("Verma Net Radiation Sensitivity Correlation")
plt.grid(axis='y')  # Add horizontal gridlines

plt.savefig("Verma Net Radiation Sensitivity Correlation.jpeg", format='jpeg', bbox_inches='tight')
plt.savefig("Verma Net Radiation Sensitivity Correlation.svg", format='svg', bbox_inches='tight')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[18], line 3
#       1 df = sensitivity_metrics_df
#       2 df = df[(df.output_variable == "Rn_Wm2") & (df.metric == "correlation")]
# ----> 3 ax = sns.barplot(x=df.input_variable, y=df.value, color='black')
#       4 ax.set_xticklabels(["Surface\nTemperature", "NDVI", "Albedo", "Air\nTemperature", "Relative\nHumidity"])
#       5 # plt.ylim(0, 0.8)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/verma-net-radiation/lib/python3.10/site-packages/seaborn/categorical.py:2380, in barplot(data, x, y, hue, order, hue_order, estimator, errorbar, n_boot, seed, units, weights, orient, color, palette, saturation, fill, hue_norm, width, dodge, gap, log_scale, native_scale, formatter, legend, capsize, err_kws, ci, errcolor, errwidth, ax, **kwargs)
#    2377 # Deprecations to remove in v0.15.0.
#    2378 err_kws, capsize = p._err_kws_backcompat(err_kws, errcolor, errwidth, capsize)
# -> 2380 p.plot_bars(
#    2381     aggregator=aggregator,
#    2382     dodge=dodge,
#    2383     width=width,
#    2384     gap=gap,
#    2385     color=color,
#    2386     fill=fill,
#    2387     capsize=capsize,
#    2388     err_kws=err_kws,
#    2389     plot_kws=kwargs,
#    2390 )
#    2392 p._add_axis_labels(ax)
#    2393 p._adjust_cat_axis(ax, axis=p.orient)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/verma-net-radiation/lib/python3.10/site-packages/seaborn/categorical.py:1273, in _CategoricalPlotter.plot_bars(self, aggregator, dodge, gap, width, fill, color, capsize, err_kws, plot_kws)
#    1269     plot_kws.setdefault("linewidth", 1.5 * mpl.rcParams["lines.linewidth"])
#    1271 err_kws.setdefault("linewidth", 1.5 * mpl.rcParams["lines.linewidth"])
# -> 1273 for sub_vars, sub_data in self.iter_data(iter_vars,
#    1274                                          from_comp_data=True,
#    1275                                          allow_empty=True):
#    1277     ax = self._get_axes(sub_vars)
#    1279     agg_data = sub_data if sub_data.empty else (
#    1280         sub_data
#    1281         .groupby(self.orient)
#    1282         .apply(aggregator, agg_var, **groupby_apply_include_groups(False))
#    1283         .reset_index()
#    1284     )
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/verma-net-radiation/lib/python3.10/site-packages/seaborn/_base.py:902, in VectorPlotter.iter_data(self, grouping_vars, reverse, from_comp_data, by_facet, allow_empty, dropna)
#     899 grouping_vars = [var for var in grouping_vars if var in self.variables]
#     901 if from_comp_data:
# --> 902     data = self.comp_data
#     903 else:
#     904     data = self.plot_data
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/verma-net-radiation/lib/python3.10/site-packages/seaborn/_base.py:1007, in VectorPlotter.comp_data(self)
#    1005         else:
#    1006             comp_col = pd.Series(dtype=float, name=var)
# -> 1007         comp_data.insert(0, var, comp_col)
#    1009     self._comp_data = comp_data
#    1011 return self._comp_data
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/verma-net-radiation/lib/python3.10/site-packages/pandas/core/frame.py:5178, in DataFrame.insert(self, loc, column, value, allow_duplicates)
#    5175 elif isinstance(value, DataFrame):
#    5176     value = value.iloc[:, 0]
# -> 5178 value, refs = self._sanitize_column(value)
#    5179 self._mgr.insert(loc, column, value, refs=refs)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/verma-net-radiation/lib/python3.10/site-packages/pandas/core/frame.py:5270, in DataFrame._sanitize_column(self, value)
#    5268     if not isinstance(value, Series):
#    5269         value = Series(value)
# -> 5270     return _reindex_for_setitem(value, self.index)
#    5272 if is_list_like(value):
#    5273     com.require_length_match(value, self.index)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/verma-net-radiation/lib/python3.10/site-packages/pandas/core/frame.py:12699, in _reindex_for_setitem(value, index)
#   12695 except ValueError as err:
#   12696     # raised in MultiIndex.from_tuples, see test_insert_error_msmgs
#   12697     if not value.index.is_unique:
#   12698         # duplicate axis
# > 12699         raise err
#   12701     raise TypeError(
#   12702         "incompatible index of inserted column with frame index"
#   12703     ) from err
#   12704 return reindexed_value, None
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/verma-net-radiation/lib/python3.10/site-packages/pandas/core/frame.py:12694, in _reindex_for_setitem(value, index)
#   12692 # GH#4107
#   12693 try:
# > 12694     reindexed_value = value.reindex(index)._values
#   12695 except ValueError as err:
#   12696     # raised in MultiIndex.from_tuples, see test_insert_error_msmgs
#   12697     if not value.index.is_unique:
#   12698         # duplicate axis
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/verma-net-radiation/lib/python3.10/site-packages/pandas/core/series.py:5164, in Series.reindex(self, index, axis, method, copy, level, fill_value, limit, tolerance)
#    5147 @doc(
#    5148     NDFrame.reindex,  # type: ignore[has-type]
#    5149     klass=_shared_doc_kwargs["klass"],
#    (...)
#    5162     tolerance=None,
#    5163 ) -> Series:
# -> 5164     return super().reindex(
#    5165         index=index,
#    5166         method=method,
#    5167         copy=copy,
#    5168         level=level,
#    5169         fill_value=fill_value,
#    5170         limit=limit,
#    5171         tolerance=tolerance,
#    5172     )
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/verma-net-radiation/lib/python3.10/site-packages/pandas/core/generic.py:5629, in NDFrame.reindex(self, labels, index, columns, axis, method, copy, level, fill_value, limit, tolerance)
#    5626     return self._reindex_multi(axes, copy, fill_value)
#    5628 # perform the reindex on the axes
# -> 5629 return self._reindex_axes(
#    5630     axes, level, limit, tolerance, method, fill_value, copy
#    5631 ).__finalize__(self, method="reindex")
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/verma-net-radiation/lib/python3.10/site-packages/pandas/core/generic.py:5652, in NDFrame._reindex_axes(self, axes, level, limit, tolerance, method, fill_value, copy)
#    5649     continue
#    5651 ax = self._get_axis(a)
# -> 5652 new_index, indexer = ax.reindex(
#    5653     labels, level=level, limit=limit, tolerance=tolerance, method=method
#    5654 )
#    5656 axis = self._get_axis_number(a)
#    5657 obj = obj._reindex_with_indexers(
#    5658     {axis: [new_index, indexer]},
#    5659     fill_value=fill_value,
#    5660     copy=copy,
#    5661     allow_dups=False,
#    5662 )
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/verma-net-radiation/lib/python3.10/site-packages/pandas/core/indexes/base.py:4436, in Index.reindex(self, target, method, level, limit, tolerance)
#    4433     raise ValueError("cannot handle a non-unique multi-index!")
#    4434 elif not self.is_unique:
#    4435     # GH#42568
# -> 4436     raise ValueError("cannot reindex on an axis with duplicate labels")
#    4437 else:
#    4438     indexer, _ = self.get_indexer_non_unique(target)
#
# ValueError: cannot reindex on an axis with duplicate labels

# %% [markdown]
# ## Summary and Next Steps
#
# This notebook demonstrated a full sensitivity analysis workflow for the PT-JPL-SM model using ECOSTRESS Cal-Val data. Key results include the identification of input variables with the greatest influence on latent heat flux. Next steps could include further exploration of model parameters, additional visualizations, or application to other datasets.
