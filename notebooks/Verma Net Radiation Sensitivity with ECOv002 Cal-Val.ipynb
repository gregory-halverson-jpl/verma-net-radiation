# %% [markdown]
# # Verma Net Radiation Sensitivity Analysis with ECOv002 Cal-Val
#
# This notebook performs a sensitivity analysis of the Verma net radiation model using ECOSTRESS Collection 2 Cal-Val data. It loads input data, processes it through the Verma net radiation model, and visualizes the impact of input perturbations on latent heat flux. The notebook also generates figures for publication and explores the relationship between surface temperature and latent heat flux.

# %% [markdown]
# ## Import Required Libraries and Functions
#
# This cell imports all necessary libraries and functions for data processing, model execution, statistical analysis, and plotting. It includes custom modules for the BESS-JPL model, sensitivity analysis, and net radiation calculations, as well as standard scientific Python libraries.

# %%
import sys
import os
sys.path.insert(0, os.path.abspath(os.path.join(os.path.dirname("__file__"), '..')))

# %%
from typing import Callable
from os import makedirs
from os.path import join
import numpy as np
import pandas as pd
from verma_net_radiation import verma_net_radiation_table, load_ECOv002_calval_verma_net_radiation_inputs
from monte_carlo_sensitivity import perturbed_run, sensitivity_analysis, divide_absolute_by_unperturbed
import matplotlib.pyplot as plt
from scipy.stats import mstats
import seaborn as sns
from matplotlib.ticker import FuncFormatter

# %% [markdown]
# ## Set Normalization Function
#
# This cell assigns the normalization function used to compare perturbed model outputs to the unperturbed baseline. The function `divide_absolute_by_unperturbed` is used for normalization in the sensitivity analysis.

# %%
normalization_function = divide_absolute_by_unperturbed

# %% [markdown]
# ## Load and Filter Input Data
#
# This cell loads the ECOSTRESS Cal-Val input data using a custom loader function. The resulting DataFrame is displayed for inspection.

# %%
input_df = load_ECOv002_calval_verma_net_radiation_inputs()
input_df
# Out:
#       Unnamed: 0      ID vegetation climate    STICinst   BESSinst  \
# 0              0  US-NC3        ENF     Cfa  270.345200   78.53355
# 1              1  US-Mi3        CVM     Dfb  232.141600  229.20093
# 2              2  US-Mi3        CVM     Dfb  356.355740  335.23154
# 3              3  US-Mi3        CVM     Dfb  332.938400  326.68680
# 4              4  US-Mi3        CVM     Dfb  286.854030  237.21654
# ...          ...     ...        ...     ...         ...        ...
# 1060        1060  US-xAE        GRA     Cfa   70.923310  172.37459
# 1061        1061  US-xAE        GRA     Cfa  116.543190  121.81641
# 1062        1062  US-xAE        GRA     Cfa  129.880100    0.00000
# 1063        1063  US-xAE        GRA     Cfa    2.707851  140.38632
# 1064        1064  US-xAE        GRA     Cfa  303.242950    0.00000
#
#        MOD16inst  PTJPLSMinst      ETinst  ETinstUncertainty  ...  \
# 0     392.851840   307.021970  487.383423         118.916280  ...
# 1     640.118470   375.089300  106.825577         167.919460  ...
# 2     625.661700   284.686250         NaN         132.936340  ...
# 3     624.254330   251.414490  178.827545         141.132420  ...
# 4     511.082180   228.520170  154.791626         114.809410  ...
# ...          ...          ...         ...                ...  ...
# 1060   81.645230    15.282976         NaN          56.385185  ...
# 1061   65.469320    22.186659         NaN          40.509410  ...
# 1062  118.777240    55.343586         NaN          52.403820  ...
# 1063  126.490524    40.434025         NaN          57.769722  ...
# 1064  271.749480   119.763630  190.823303         122.092445  ...
#
#              EndDate  LE_count  closure_ratio                  geometry  \
# 0       1/1/22 05:00      9576           1.02    POINT (-76.656 35.799)
# 1     12/28/19 04:00     12170           0.92   POINT (-80.637 41.8222)
# 2     12/28/19 04:00     12170           0.92   POINT (-80.637 41.8222)
# 3     12/28/19 04:00     12170           0.92   POINT (-80.637 41.8222)
# 4     12/28/19 04:00     12170           0.92   POINT (-80.637 41.8222)
# ...              ...       ...            ...                       ...
# 1060   12/1/22 00:00     29615           0.60  POINT (-99.0588 35.4106)
# 1061   12/1/22 00:00     29615           0.60  POINT (-99.0588 35.4106)
# 1062   12/1/22 00:00     29615           0.60  POINT (-99.0588 35.4106)
# 1063   12/1/22 00:00     29615           0.60  POINT (-99.0588 35.4106)
# 1064   12/1/22 00:00     29615           0.60  POINT (-99.0588 35.4106)
#
#                  time_UTC    ST_K   ST_C       Ta_C   SWin_Wm2  emissivity
# 0     2019-10-02 19:09:40  305.10  31.95  32.658920  545.51056       0.948
# 1     2019-06-23 18:17:17  304.34  31.19  24.227982  848.34390       0.952
# 2     2019-06-27 16:35:42  304.06  30.91  26.178862  838.81160       0.972
# 3     2019-06-30 15:44:10  301.80  28.65  22.527096  851.72480       0.974
# 4     2019-07-01 14:53:48  303.18  30.03  23.280691  702.55160       0.960
# ...                   ...     ...    ...        ...        ...         ...
# 1060  2021-12-11 16:01:12  278.78   5.63   3.815752  286.84660       0.980
# 1061  2022-03-25 22:45:31  293.28  20.13  19.266186  290.87400       0.976
# 1062  2022-04-12 22:53:09  301.94  28.79  32.110336  352.19530       0.976
# 1063  2022-04-14 14:45:37  290.72  17.57  10.464681  420.67880       0.976
# 1064  2022-04-20 19:38:47  314.76  41.61  30.316103  781.84110       0.978
#
# [1065 rows x 77 columns]

# %% [markdown]
# ## Process Input Data Through Model
#
# This cell applies the processing function to the filtered input data, running it through the Verma net radiation and PT-JPL-SM model, and displays the resulting DataFrame.

# %%
processed = verma_net_radiation_table(input_df)
processed
# Out:
# [2025-09-10 11:44:54 INFO] starting Verma net radiation processing
# [2025-09-10 11:44:54 INFO] variable SWout_Wm2 min: 0.000 mean: 66.193 max: 278.058 nan: 0.00% (nan)
# [2025-09-10 11:44:54 INFO] variable SWnet_Wm2 min: 0.000 mean: 540.741 max: 929.140 nan: 0.00% (nan)
# [2025-09-10 11:44:54 INFO] variable LWin_Wm2 min: 175.737 mean: 343.651 max: 473.521 nan: 0.00% (nan)
# [2025-09-10 11:44:54 INFO] variable LWout_Wm2 min: 240.846 mean: 462.295 max: 693.334 nan: 0.00% (nan)
# [2025-09-10 11:44:54 INFO] variable Rn_Wm2 min: 0.000 mean: 422.206 max: 843.390 nan: 0.00% (nan)
# [2025-09-10 11:44:54 INFO] variable Rn_daylight_Wm2 min: 0.000 mean: 257.722 max: 443.569 nan: 0.00% (nan)
# [2025-09-10 11:44:54 INFO] Verma net radiation processing complete in 0.02 seconds
#       Unnamed: 0      ID vegetation climate    STICinst   BESSinst  \
# 0              0  US-NC3        ENF     Cfa  270.345200   78.53355
# 1              1  US-Mi3        CVM     Dfb  232.141600  229.20093
# 2              2  US-Mi3        CVM     Dfb  356.355740  335.23154
# 3              3  US-Mi3        CVM     Dfb  332.938400  326.68680
# 4              4  US-Mi3        CVM     Dfb  286.854030  237.21654
# ...          ...     ...        ...     ...         ...        ...
# 1060        1060  US-xAE        GRA     Cfa   70.923310  172.37459
# 1061        1061  US-xAE        GRA     Cfa  116.543190  121.81641
# 1062        1062  US-xAE        GRA     Cfa  129.880100    0.00000
# 1063        1063  US-xAE        GRA     Cfa    2.707851  140.38632
# 1064        1064  US-xAE        GRA     Cfa  303.242950    0.00000
#
#        MOD16inst  PTJPLSMinst      ETinst  ETinstUncertainty  ...   ST_C  \
# 0     392.851840   307.021970  487.383423         118.916280  ...  31.95
# 1     640.118470   375.089300  106.825577         167.919460  ...  31.19
# 2     625.661700   284.686250         NaN         132.936340  ...  30.91
# 3     624.254330   251.414490  178.827545         141.132420  ...  28.65
# 4     511.082180   228.520170  154.791626         114.809410  ...  30.03
# ...          ...          ...         ...                ...  ...    ...
# 1060   81.645230    15.282976         NaN          56.385185  ...   5.63
# 1061   65.469320    22.186659         NaN          40.509410  ...  20.13
# 1062  118.777240    55.343586         NaN          52.403820  ...  28.79
# 1063  126.490524    40.434025         NaN          57.769722  ...  17.57
# 1064  271.749480   119.763630  190.823303         122.092445  ...  41.61
#
#            Ta_C   SWin_Wm2  emissivity   SWout_Wm2   SWnet_Wm2    LWin_Wm2  \
# 0     32.658920  545.51056       0.948  117.527293  427.983267  433.191382
# 1     24.227982  848.34390       0.952   99.458206  748.885694  355.960473
# 2     26.178862  838.81160       0.972   98.376177  740.435423  385.005187
# 3     22.527096  851.72480       0.974   72.080661  779.644139  357.100788
# 4     23.280691  702.55160       0.960   84.676015  617.875585  358.727378
# ...         ...        ...         ...         ...         ...         ...
# 1060   3.815752  286.84660       0.980   26.634684  260.211916  237.686968
# 1061  19.266186  290.87400       0.976   32.532471  258.341529  317.465236
# 1062  32.110336  352.19530       0.976   37.608161  314.587139  401.910116
# 1063  10.464681  420.67880       0.976   44.918145  375.760655  266.094367
# 1064  30.316103  781.84110       0.978   88.477189  693.363911  393.574271
#
#        LWout_Wm2      Rn_Wm2  Rn_daylight_Wm2
# 0     465.788054  395.386594       236.387027
# 1     463.110120  641.736047       332.853921
# 2     471.101631  654.338979       337.738360
# 3     458.191551  678.553376       366.977454
# 4     459.922447  516.680516       303.069593
# ...          ...         ...              ...
# 1060  335.647726  162.251159       123.775635
# 1061  409.440488  166.366277       178.058285
# 1062  459.984925  256.512330       262.883413
# 1063  395.330786  246.524236       212.287292
# 1064  544.337406  542.600776       285.234441
#
# [1065 rows x 83 columns]

# %%
processed.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'vegetation', 'climate', 'STICinst', 'BESSinst',
#        'MOD16inst', 'PTJPLSMinst', 'ETinst', 'ETinstUncertainty', 'PET', 'Rn',
#        'ESI', 'RH', 'Ta', 'LST', 'SM', 'NDVI', 'NDVI-UQ', 'albedo',
#        'albedo-UQ', 'LST_err', 'view_zenith', 'Rg', 'EmisWB', 'time_utc',
#        'solar_time', 'solar_hour', 'local_time', 'LE', 'LE_filt', 'LEcorr25',
#        'LEcorr50', 'LEcorr75', 'LEcorr_ann', 'H_filt', 'Hcorr25', 'Hcorr50',
#        'Hcorr75', 'Hcorr_ann', 'NETRAD_filt', 'G_filt', 'SM_surf', 'SM_rz',
#        'AirTempC', 'SW_IN', 'RH_percentage', 'ESIrn_STIC', 'ESIrn_PTJPLSM',
#        'ESIrn_MOD16', 'ESIrn_BESS', 'ESIrn_Unc_ECO', 'ESIrn_LEcorr50', 'JET',
#        'eco_time_utc', 'Site Name', 'Date-Time', 'Site ID', 'Name', 'Lat',
#        'Long', 'Elev', 'Clim', 'Veg', 'MAT', 'MAP', 'StartDate', 'EndDate',
#        'LE_count', 'closure_ratio', 'geometry', 'time_UTC', 'ST_K', 'ST_C',
#        'Ta_C', 'SWin_Wm2', 'emissivity', 'SWout_Wm2', 'SWnet_Wm2', 'LWin_Wm2',
#        'LWout_Wm2', 'Rn_Wm2', 'Rn_daylight_Wm2'],
#       dtype='object')

# %%
## Accuracy Comparison of In-Situ Net Radiation to Verma Net Radiation

# %%
sc = plt.scatter(
    x=processed.NETRAD_filt,
    y=processed.Rn_Wm2,
    c=processed.ST_C,
    cmap="jet",
    color=None,
    s=5
)

# Add 1-to-1 line
min_val = min(processed.NETRAD_filt.min(), processed.Rn_Wm2.min())
max_val = max(processed.NETRAD_filt.max(), processed.Rn_Wm2.max())
plt.plot([min_val, max_val], [min_val, max_val], color='black', linestyle='-', linewidth=1, label='1:1 Line')

# Add OLS regression line
coefs = np.polyfit(processed.NETRAD_filt, processed.Rn_Wm2, 1)
ols_x = np.array([min_val, max_val])
ols_y = coefs[0] * ols_x + coefs[1]
plt.plot(ols_x, ols_y, color='black', linestyle='--', linewidth=1, label='OLS Fit')

# Calculate R-squared and RMSE
from sklearn.metrics import r2_score, mean_squared_error
y_true = processed.Rn_Wm2
y_pred = coefs[0] * processed.NETRAD_filt + coefs[1]
r2 = r2_score(y_true, y_pred)
rmse = np.sqrt(mean_squared_error(y_true, y_pred))

# Annotate R-squared and RMSE on plot
plt.annotate(f"$R^2$ = {r2:.2f}\nRMSE = {rmse:.1f}",
             xy=(0.05, 0.95), xycoords='axes fraction',
             ha='left', va='top',
             fontsize=10,
             bbox=dict(boxstyle='round', fc='white', ec='gray', alpha=0.7))

# Set ticks every 100 for both axes
xticks = np.arange(100 * (min_val // 100), 100 * (max_val // 100 + 2), 100)
yticks = np.arange(100 * (min_val // 100), 100 * (max_val // 100 + 2), 100)
plt.xticks(xticks)
plt.yticks(yticks)

plt.grid(True, zorder=0) 
plt.xlabel("In-Situ Net Radiation (W/m$^2$)")
plt.ylabel("Verma Net Radiation (W/m$^2$)")
plt.title("Accuracy Comparison\nof In-Situ Net Radiation\nto Verma Net Radiation")
plt.colorbar(sc, label="ECOSTRESS Surface Temperature (°C)")
plt.legend()
plt.savefig("Unperturbed Comparison of In-Situ Net Radiation to Verma Net Radiation.jpeg", format='jpeg', bbox_inches='tight')
plt.savefig("Unperturbed Comparison of In-Situ Net Radiation to Verma Net Radiation.svg", format='svg', bbox_inches='tight')
plt.show()

# %% [markdown]
# ## Plot Unperturbed Comparison of Surface Temperature to Latent Heat Flux
#
# This cell creates a scatter plot comparing ECOSTRESS surface temperature to PT-JPL-SM latent heat flux for the unperturbed data. The plot is saved as both JPEG and SVG files for publication or further analysis.

# %%
plt.xticks(range(int(min(processed.ST_C)), int(max(processed.ST_C)) + 1, 5))
plt.scatter(x=processed.ST_C, y=processed.Rn_Wm2, color='black', s=10, zorder=5)
plt.grid(True, zorder=0)
plt.xlabel("ECOSTRESS Surface Temperature (°C)")
plt.ylabel("Verma Net Radiation (W/m$^2$)")
plt.title("Unperturbed Comparison\nof ECOSTRESS Surface Temperature\nto Verma Net Radiation")

plt.savefig("Unperturbed Comparison of ECOSTRESS Surface Temperature to Verma Net Radiation.jpeg", format='jpeg', bbox_inches='tight')
plt.savefig("Unperturbed Comparison of ECOSTRESS Surface Temperature to Verma Net Radiation.svg", format='svg', bbox_inches='tight')

plt.show()

# %% [markdown]
# ## Further Filter Input Data and Check Temperature Range
#
# This cell applies additional filters to the input data, ensuring only valid `fAPARmax` and `NDVI` values are included. It also checks the minimum and maximum surface temperature values in the filtered dataset.

# %%
# input_df = pd.read_csv(input_filename)
input_df = load_ECOv002_calval_verma_net_radiation_inputs()

if "Ta" in input_df and "Ta_C" not in input_df:
    # input_df.rename({"Ta": "Ta_C"}, inplace=True)
    input_df["Ta_C"] = input_df["Ta"]

input_df = input_df[input_df.NDVI.apply(lambda NDVI: NDVI > 0.05)]

np.nanmin(input_df.ST_C), np.nanmax(input_df.ST_C)
# Out:
# (np.float64(-13.189999999999998), np.float64(86.11000000000001))

# %% [markdown]
# ## Check Number of Valid Input Rows
#
# This cell displays the number of rows remaining in the input DataFrame after all filtering steps, confirming the size of the dataset used for analysis.

# %%
len(input_df)
# Out:
# 1063

# %% [markdown]
# ## Run Perturbed Model Analysis
#
# This cell sets up the input and output variables for the sensitivity analysis and runs the `perturbed_run` function, which perturbs the input variable and observes the effect on the output variable using the PT-JPL-SM model. The results are displayed for further analysis.

# %%
input_variable = "ST_C"
output_variable = "Rn_Wm2"

results = perturbed_run(
    input_df=input_df, 
    input_variable=input_variable, 
    output_variable=output_variable, 
    forward_process=verma_net_radiation_table,
    normalization_function=normalization_function
)

results
# Out:
# [2025-09-10 11:44:54 INFO] tarting Monte Carlo perturbed run
# [2025-09-10 11:44:54 INFO] calculating standard deviation of input variable: ST_C
# [2025-09-10 11:44:54 INFO] input variable ST_C standard deviation: 12.285657205245933
# [2025-09-10 11:44:54 INFO] starting forward process
# [2025-09-10 11:44:54 INFO] starting Verma net radiation processing
# [2025-09-10 11:44:54 INFO] variable SWout_Wm2 min: 0.000 mean: 65.951 max: 278.058 nan: 0.00% (nan)
# [2025-09-10 11:44:54 INFO] variable SWnet_Wm2 min: 0.000 mean: 541.474 max: 929.140 nan: 0.00% (nan)
# [2025-09-10 11:44:54 INFO] variable LWin_Wm2 min: 175.737 mean: 343.933 max: 473.521 nan: 0.00% (nan)
# [2025-09-10 11:44:54 INFO] variable LWout_Wm2 min: 248.604 mean: 462.692 max: 693.334 nan: 0.00% (nan)
# [2025-09-10 11:44:54 INFO] variable Rn_Wm2 min: 0.000 mean: 422.824 max: 843.390 nan: 0.00% (nan)
# [2025-09-10 11:44:54 INFO] variable Rn_daylight_Wm2 min: 0.000 mean: 258.106 max: 443.569 nan: 0.00% (nan)
# [2025-09-10 11:44:54 INFO] Verma net radiation processing complete in 0.02 seconds
# [2025-09-10 11:44:54 INFO] forward process completed
# [2025-09-10 11:44:54 INFO] calculating standard deviation of output variable: Rn_Wm2
# [2025-09-10 11:44:54 INFO] output variable Rn_Wm2 standard deviation: 149.08451152972577
# [2025-09-10 11:44:54 INFO] starting input perturbation generation
# [2025-09-10 11:44:54 INFO] input perturbation generation completed
# [2025-09-10 11:44:54 INFO] generating control group
# [2025-09-10 11:44:54 INFO] normalizing input perturbations
# [2025-09-10 11:44:54 INFO] applying perturbations
# [2025-09-10 11:44:54 INFO] starting forward process for perturbed input
# [2025-09-10 11:44:55 INFO] starting Verma net radiation processing
# [2025-09-10 11:44:55 INFO] variable SWout_Wm2 min: 0.000 mean: 65.951 max: 278.058 nan: 0.00% (nan)
# [2025-09-10 11:44:55 INFO] variable SWnet_Wm2 min: 0.000 mean: 541.474 max: 929.140 nan: 0.00% (nan)
# [2025-09-10 11:44:55 INFO] variable LWin_Wm2 min: 175.737 mean: 343.933 max: 473.521 nan: 0.00% (nan)
# [2025-09-10 11:44:56 INFO] variable LWout_Wm2 min: 150.071 mean: 467.413 max: 1029.723 nan: 0.00% (nan)
# [2025-09-10 11:44:56 INFO] variable Rn_Wm2 min: 0.000 mean: 418.363 max: 1017.950 nan: 0.00% (nan)
# [2025-09-10 11:44:57 INFO] variable Rn_daylight_Wm2 min: 0.000 mean: 255.295 max: 541.324 nan: 0.00% (nan)
# [2025-09-10 11:44:57 INFO] Verma net radiation processing complete in 1.27 seconds
# [2025-09-10 11:44:57 INFO] completed forward process for perturbed input
# [2025-09-10 11:44:57 INFO] normalizing output perturbations
# [2025-09-10 11:44:57 INFO] Monte Carlo run complete
#        input_variable output_variable input_unperturbed  input_perturbation  \
# 0                ST_C          Rn_Wm2             31.95            6.976811
# 1                ST_C          Rn_Wm2             31.95           16.205590
# 2                ST_C          Rn_Wm2             31.95          -11.177609
# 3                ST_C          Rn_Wm2             31.95            3.400472
# 4                ST_C          Rn_Wm2             31.95           -8.181642
# ...               ...             ...               ...                 ...
# 106295           ST_C          Rn_Wm2             41.61           -2.584604
# 106296           ST_C          Rn_Wm2             41.61           -3.517741
# 106297           ST_C          Rn_Wm2             41.61           -0.116701
# 106298           ST_C          Rn_Wm2             41.61           10.047164
# 106299           ST_C          Rn_Wm2             41.61          -18.697081
#
#         input_perturbation_std input_perturbed output_unperturbed  \
# 0                     0.218367       38.926811         395.386594
# 1                     0.507217        48.15559         395.386594
# 2                     0.349847       20.772391         395.386594
# 3                     0.106431       35.350472         395.386594
# 4                     0.256076       23.768358         395.386594
# ...                        ...             ...                ...
# 106295                0.062115       39.025396         542.600776
# 106296                0.084541       38.092259         542.600776
# 106297                0.002805       41.493299         542.600776
# 106298                0.241460       51.657164         542.600776
# 106299                0.449341       22.912919         542.600776
#
#        output_perturbation output_perturbation_std output_perturbed
# 0               -44.089053                0.111509       351.297541
# 1              -107.130177                 0.27095       288.256417
# 2                64.597957                0.163379       459.984551
# 3                -21.11539                0.053404       374.271204
# 4                47.988745                0.121372       443.375339
# ...                    ...                     ...              ...
# 106295           17.659966                0.032547       560.260742
# 106296           23.929045                0.044101       566.529822
# 106297            0.806829                0.001487       543.407605
# 106298          -72.900274                0.134353       469.700502
# 106299          118.262358                0.217955       660.863135
#
# [105900 rows x 10 columns]

# %% [markdown]
# ## Filter Out NaN Results
#
# This cell removes any rows with missing values from the perturbed results to ensure only valid data points are used in subsequent analysis and plotting.

# %%
filtered_results = results.dropna()
filtered_results
# Out:
#        input_variable output_variable input_unperturbed  input_perturbation  \
# 0                ST_C          Rn_Wm2             31.95            6.976811
# 1                ST_C          Rn_Wm2             31.95           16.205590
# 2                ST_C          Rn_Wm2             31.95          -11.177609
# 3                ST_C          Rn_Wm2             31.95            3.400472
# 4                ST_C          Rn_Wm2             31.95           -8.181642
# ...               ...             ...               ...                 ...
# 106295           ST_C          Rn_Wm2             41.61           -2.584604
# 106296           ST_C          Rn_Wm2             41.61           -3.517741
# 106297           ST_C          Rn_Wm2             41.61           -0.116701
# 106298           ST_C          Rn_Wm2             41.61           10.047164
# 106299           ST_C          Rn_Wm2             41.61          -18.697081
#
#         input_perturbation_std input_perturbed output_unperturbed  \
# 0                     0.218367       38.926811         395.386594
# 1                     0.507217        48.15559         395.386594
# 2                     0.349847       20.772391         395.386594
# 3                     0.106431       35.350472         395.386594
# 4                     0.256076       23.768358         395.386594
# ...                        ...             ...                ...
# 106295                0.062115       39.025396         542.600776
# 106296                0.084541       38.092259         542.600776
# 106297                0.002805       41.493299         542.600776
# 106298                0.241460       51.657164         542.600776
# 106299                0.449341       22.912919         542.600776
#
#        output_perturbation output_perturbation_std output_perturbed
# 0               -44.089053                0.111509       351.297541
# 1              -107.130177                 0.27095       288.256417
# 2                64.597957                0.163379       459.984551
# 3                -21.11539                0.053404       374.271204
# 4                47.988745                0.121372       443.375339
# ...                    ...                     ...              ...
# 106295           17.659966                0.032547       560.260742
# 106296           23.929045                0.044101       566.529822
# 106297            0.806829                0.001487       543.407605
# 106298          -72.900274                0.134353       469.700502
# 106299          118.262358                0.217955       660.863135
#
# [105900 rows x 10 columns]

# %% [markdown]
# ## Plot Change in Surface Temperature vs Net Radiation
#
# This cell generates a scatter plot showing the relationship between changes in surface temperature and changes in Verma net radiation due to input perturbations. The plot is saved as JPEG and SVG files.

# %%
# plt.xticks(range(int(min(processed.ST_C)), int(max(processed.ST_C)) + 1, 5))
# plt.ylim(-350, 150)
plt.scatter(x=results.input_perturbation, y=results.output_perturbation, color='black', s=10, zorder=5)  # Adjust the 's' parameter to make dots thinner
plt.grid(True, zorder=0)
plt.xlabel("Change in Surface Temperature (°C)")
plt.ylabel("Change in Verma Net Radiation (W/m$^2$)")
plt.title("Comparison of Change\nin Surface Temperature\nto Verma Net Radiation")

plt.savefig("Comparison of Change in Surface Temperature to Verma Net Radiation.jpeg", format='jpeg', bbox_inches='tight')
plt.savefig("Comparison of Change in Surface Temperature to Verma Net Radiation.svg", format='svg', bbox_inches='tight')

plt.show()

# %%
sc = plt.scatter(
    x=results.input_perturbation, 
    y=results.output_perturbation, 
    c=results.input_unperturbed, 
    color=None,
    cmap="jet",
    s=3,
    alpha=0.5, 
    zorder=5
)

plt.grid(True, zorder=0)
plt.xlabel("Change in Surface Temperature (°C)")
plt.ylabel("Change in Verma Net Radiation (W/m$^2$)")
plt.title("Comparison of Change\nin Surface Temperature\nto Verma Net Radiation", pad=20)
plt.colorbar(sc, label="ECOSTRESS Surface Temperature (°C)")
plt.savefig("Comparison of Change in Surface Temperature to Verma Net Radiation.jpeg", format='jpeg', bbox_inches='tight')
plt.savefig("Comparison of Change in Surface Temperature to Verma Net Radiation.svg", format='svg', bbox_inches='tight')

plt.show()

# %% [markdown]
# ## Compute Correlation Between Input and Output Perturbations
#
# This cell calculates the Pearson correlation coefficient between the standardized input and output perturbations, quantifying the strength of their linear relationship.

# %%
correlation = mstats.pearsonr(
    np.array(filtered_results.input_perturbation_std).astype(np.float64), 
    np.array(filtered_results.output_perturbation_std).astype(np.float64)
)[0]

correlation
# Out:
# np.float64(0.022651644182882628)

# %% [markdown]
# ## Run Full Sensitivity Analysis for Multiple Inputs
#
# This cell performs a comprehensive sensitivity analysis by perturbing several input variables (surface temperature, NDVI, albedo, air temperature, relative humidity) and measuring their effect on latent heat flux. The results are summarized in a DataFrame.

# %%
input_variables = ["ST_C", "albedo", "Ta_C", "RH"]
output_variables = ["Rn_Wm2"]

perturbation_df, sensitivity_metrics_df = sensitivity_analysis(
    input_df=input_df,
    input_variables=input_variables,
    output_variables=output_variables,
    forward_process=verma_net_radiation_table,
    normalization_function=normalization_function
)

sensitivity_metrics_df
# Out:
# [2025-09-10 11:45:04 INFO] tarting Monte Carlo perturbed run
# [2025-09-10 11:45:04 INFO] calculating standard deviation of input variable: ST_C
# [2025-09-10 11:45:04 INFO] input variable ST_C standard deviation: 12.285657205245933
# [2025-09-10 11:45:04 INFO] starting forward process
# [2025-09-10 11:45:04 INFO] starting Verma net radiation processing
# [2025-09-10 11:45:04 INFO] variable SWout_Wm2 min: 0.000 mean: 65.951 max: 278.058 nan: 0.00% (nan)
# [2025-09-10 11:45:04 INFO] variable SWnet_Wm2 min: 0.000 mean: 541.474 max: 929.140 nan: 0.00% (nan)
# [2025-09-10 11:45:04 INFO] variable LWin_Wm2 min: 175.737 mean: 343.933 max: 473.521 nan: 0.00% (nan)
# [2025-09-10 11:45:04 INFO] variable LWout_Wm2 min: 248.604 mean: 462.692 max: 693.334 nan: 0.00% (nan)
# [2025-09-10 11:45:04 INFO] variable Rn_Wm2 min: 0.000 mean: 422.824 max: 843.390 nan: 0.00% (nan)
# [2025-09-10 11:45:04 INFO] variable Rn_daylight_Wm2 min: 0.000 mean: 258.106 max: 443.569 nan: 0.00% (nan)
# [2025-09-10 11:45:04 INFO] Verma net radiation processing complete in 0.02 seconds
# [2025-09-10 11:45:04 INFO] forward process completed
# [2025-09-10 11:45:04 INFO] calculating standard deviation of output variable: Rn_Wm2
# [2025-09-10 11:45:04 INFO] output variable Rn_Wm2 standard deviation: 149.08451152972577
# [2025-09-10 11:45:04 INFO] starting input perturbation generation
# [2025-09-10 11:45:04 INFO] input perturbation generation completed
# [2025-09-10 11:45:04 INFO] generating control group
# [2025-09-10 11:45:04 INFO] normalizing input perturbations
# [2025-09-10 11:45:04 INFO] applying perturbations
# [2025-09-10 11:45:04 INFO] starting forward process for perturbed input
# [2025-09-10 11:45:05 INFO] starting Verma net radiation processing
# [2025-09-10 11:45:05 INFO] variable SWout_Wm2 min: 0.000 mean: 65.951 max: 278.058 nan: 0.00% (nan)
# [2025-09-10 11:45:05 INFO] variable SWnet_Wm2 min: 0.000 mean: 541.474 max: 929.140 nan: 0.00% (nan)
# [2025-09-10 11:45:05 INFO] variable LWin_Wm2 min: 175.737 mean: 343.933 max: 473.521 nan: 0.00% (nan)
# [2025-09-10 11:45:05 INFO] variable LWout_Wm2 min: 133.952 mean: 467.435 max: 1055.907 nan: 0.00% (nan)
# [2025-09-10 11:45:05 INFO] variable Rn_Wm2 min: 0.000 mean: 418.292 max: 1009.628 nan: 0.00% (nan)
# [2025-09-10 11:45:06 INFO] variable Rn_daylight_Wm2 min: 0.000 mean: 255.236 max: 589.917 nan: 0.00% (nan)
# [2025-09-10 11:45:06 INFO] Verma net radiation processing complete in 1.32 seconds
# [2025-09-10 11:45:06 INFO] completed forward process for perturbed input
# [2025-09-10 11:45:06 INFO] normalizing output perturbations
# [2025-09-10 11:45:06 INFO] Monte Carlo run complete
# [2025-09-10 11:45:06 INFO] tarting Monte Carlo perturbed run
# [2025-09-10 11:45:06 INFO] calculating standard deviation of input variable: albedo
# [2025-09-10 11:45:06 INFO] input variable albedo standard deviation: 0.05366279984322165
# [2025-09-10 11:45:06 INFO] starting forward process
# [2025-09-10 11:45:06 INFO] starting Verma net radiation processing
# [2025-09-10 11:45:06 INFO] variable SWout_Wm2 min: 0.000 mean: 65.951 max: 278.058 nan: 0.00% (nan)
# [2025-09-10 11:45:06 INFO] variable SWnet_Wm2 min: 0.000 mean: 541.474 max: 929.140 nan: 0.00% (nan)
# [2025-09-10 11:45:06 INFO] variable LWin_Wm2 min: 175.737 mean: 343.933 max: 473.521 nan: 0.00% (nan)
# [2025-09-10 11:45:06 INFO] variable LWout_Wm2 min: 248.604 mean: 462.692 max: 693.334 nan: 0.00% (nan)
# [2025-09-10 11:45:06 INFO] variable Rn_Wm2 min: 0.000 mean: 422.824 max: 843.390 nan: 0.00% (nan)
# [2025-09-10 11:45:07 INFO] variable Rn_daylight_Wm2 min: 0.000 mean: 258.106 max: 443.569 nan: 0.00% (nan)
# [2025-09-10 11:45:07 INFO] Verma net radiation processing complete in 0.02 seconds
# [2025-09-10 11:45:07 INFO] forward process completed
# [2025-09-10 11:45:07 INFO] calculating standard deviation of output variable: Rn_Wm2
# [2025-09-10 11:45:07 INFO] output variable Rn_Wm2 standard deviation: 149.08451152972577
# [2025-09-10 11:45:07 INFO] starting input perturbation generation
# [2025-09-10 11:45:07 INFO] input perturbation generation completed
# [2025-09-10 11:45:07 INFO] generating control group
# [2025-09-10 11:45:07 INFO] normalizing input perturbations
# [2025-09-10 11:45:07 INFO] applying perturbations
# [2025-09-10 11:45:07 INFO] starting forward process for perturbed input
# /opt/homebrew/Caskroom/miniforge/base/envs/verma-net-radiation/lib/python3.10/site-packages/monte_carlo_sensitivity/sensitivity_analysis.py:77: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   perturbation_df = pd.concat([perturbation_df, run_results])
# /opt/homebrew/Caskroom/miniforge/base/envs/verma-net-radiation/lib/python3.10/site-packages/monte_carlo_sensitivity/sensitivity_analysis.py:89: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   sensitivity_metrics_df = pd.concat([sensitivity_metrics_df, pd.DataFrame([[
# [2025-09-10 11:45:08 INFO] starting Verma net radiation processing
# [2025-09-10 11:45:08 INFO] variable SWout_Wm2 min: 0.000 mean: 66.816 max: 438.914 nan: 0.00% (nan)
# [2025-09-10 11:45:08 INFO] variable SWnet_Wm2 min: 0.000 mean: 540.610 max: 1042.937 nan: 0.00% (nan)
# [2025-09-10 11:45:08 INFO] variable LWin_Wm2 min: 175.737 mean: 343.933 max: 473.521 nan: 0.00% (nan)
# [2025-09-10 11:45:08 INFO] variable LWout_Wm2 min: 248.604 mean: 462.692 max: 693.334 nan: 0.00% (nan)
# [2025-09-10 11:45:08 INFO] variable Rn_Wm2 min: 0.000 mean: 421.970 max: 957.188 nan: 0.00% (nan)
# [2025-09-10 11:45:09 INFO] variable Rn_daylight_Wm2 min: 0.000 mean: 257.581 max: 503.419 nan: 0.00% (nan)
# [2025-09-10 11:45:09 INFO] Verma net radiation processing complete in 1.32 seconds
# [2025-09-10 11:45:09 INFO] completed forward process for perturbed input
# [2025-09-10 11:45:09 INFO] normalizing output perturbations
# [2025-09-10 11:45:09 INFO] Monte Carlo run complete
# [2025-09-10 11:45:09 INFO] tarting Monte Carlo perturbed run
# [2025-09-10 11:45:09 INFO] calculating standard deviation of input variable: Ta_C
# [2025-09-10 11:45:09 INFO] input variable Ta_C standard deviation: 8.298861169388706
# [2025-09-10 11:45:09 INFO] starting forward process
# [2025-09-10 11:45:09 INFO] starting Verma net radiation processing
# [2025-09-10 11:45:09 INFO] variable SWout_Wm2 min: 0.000 mean: 65.951 max: 278.058 nan: 0.00% (nan)
# [2025-09-10 11:45:09 INFO] variable SWnet_Wm2 min: 0.000 mean: 541.474 max: 929.140 nan: 0.00% (nan)
# [2025-09-10 11:45:09 INFO] variable LWin_Wm2 min: 175.737 mean: 343.933 max: 473.521 nan: 0.00% (nan)
# [2025-09-10 11:45:09 INFO] variable LWout_Wm2 min: 248.604 mean: 462.692 max: 693.334 nan: 0.00% (nan)
# [2025-09-10 11:45:09 INFO] variable Rn_Wm2 min: 0.000 mean: 422.824 max: 843.390 nan: 0.00% (nan)
# [2025-09-10 11:45:09 INFO] variable Rn_daylight_Wm2 min: 0.000 mean: 258.106 max: 443.569 nan: 0.00% (nan)
# [2025-09-10 11:45:09 INFO] Verma net radiation processing complete in 0.02 seconds
# [2025-09-10 11:45:09 INFO] forward process completed
# [2025-09-10 11:45:09 INFO] calculating standard deviation of output variable: Rn_Wm2
# [2025-09-10 11:45:09 INFO] output variable Rn_Wm2 standard deviation: 149.08451152972577
# [2025-09-10 11:45:09 INFO] starting input perturbation generation
# [2025-09-10 11:45:09 INFO] input perturbation generation completed
# [2025-09-10 11:45:09 INFO] generating control group
# [2025-09-10 11:45:09 INFO] normalizing input perturbations
# [2025-09-10 11:45:09 INFO] applying perturbations
# [2025-09-10 11:45:09 INFO] starting forward process for perturbed input
# [2025-09-10 11:45:10 INFO] starting Verma net radiation processing
# [2025-09-10 11:45:10 INFO] variable SWout_Wm2 min: 0.000 mean: 65.951 max: 278.058 nan: 0.00% (nan)
# [2025-09-10 11:45:10 INFO] variable SWnet_Wm2 min: 0.000 mean: 541.474 max: 929.140 nan: 0.00% (nan)
# [2025-09-10 11:45:10 INFO] variable LWin_Wm2 min: 115.320 mean: 348.765 max: 723.792 nan: 0.00% (nan)
# [2025-09-10 11:45:10 INFO] variable LWout_Wm2 min: 248.604 mean: 462.692 max: 693.334 nan: 0.00% (nan)
# [2025-09-10 11:45:10 INFO] variable Rn_Wm2 min: 0.000 mean: 427.728 max: 1052.370 nan: 0.00% (nan)
# [2025-09-10 11:45:11 INFO] variable Rn_daylight_Wm2 min: 0.000 mean: 261.344 max: 580.026 nan: 0.00% (nan)
# [2025-09-10 11:45:11 INFO] Verma net radiation processing complete in 1.24 seconds
# [2025-09-10 11:45:12 INFO] completed forward process for perturbed input
# [2025-09-10 11:45:12 INFO] normalizing output perturbations
# [2025-09-10 11:45:12 INFO] Monte Carlo run complete
# [2025-09-10 11:45:12 INFO] tarting Monte Carlo perturbed run
# [2025-09-10 11:45:12 INFO] calculating standard deviation of input variable: RH
# [2025-09-10 11:45:12 INFO] input variable RH standard deviation: 0.12004046934391559
# [2025-09-10 11:45:12 INFO] starting forward process
# [2025-09-10 11:45:12 INFO] starting Verma net radiation processing
# [2025-09-10 11:45:12 INFO] variable SWout_Wm2 min: 0.000 mean: 65.951 max: 278.058 nan: 0.00% (nan)
# [2025-09-10 11:45:12 INFO] variable SWnet_Wm2 min: 0.000 mean: 541.474 max: 929.140 nan: 0.00% (nan)
# [2025-09-10 11:45:12 INFO] variable LWin_Wm2 min: 175.737 mean: 343.933 max: 473.521 nan: 0.00% (nan)
# [2025-09-10 11:45:12 INFO] variable LWout_Wm2 min: 248.604 mean: 462.692 max: 693.334 nan: 0.00% (nan)
# [2025-09-10 11:45:12 INFO] variable Rn_Wm2 min: 0.000 mean: 422.824 max: 843.390 nan: 0.00% (nan)
# [2025-09-10 11:45:12 INFO] variable Rn_daylight_Wm2 min: 0.000 mean: 258.106 max: 443.569 nan: 0.00% (nan)
# [2025-09-10 11:45:12 INFO] Verma net radiation processing complete in 0.02 seconds
# [2025-09-10 11:45:12 INFO] forward process completed
# [2025-09-10 11:45:12 INFO] calculating standard deviation of output variable: Rn_Wm2
# [2025-09-10 11:45:12 INFO] output variable Rn_Wm2 standard deviation: 149.08451152972577
# [2025-09-10 11:45:12 INFO] starting input perturbation generation
# [2025-09-10 11:45:12 INFO] input perturbation generation completed
# [2025-09-10 11:45:12 INFO] generating control group
# [2025-09-10 11:45:12 INFO] normalizing input perturbations
# [2025-09-10 11:45:12 INFO] applying perturbations
# [2025-09-10 11:45:12 INFO] starting forward process for perturbed input
# [2025-09-10 11:45:13 INFO] starting Verma net radiation processing
# [2025-09-10 11:45:13 INFO] variable SWout_Wm2 min: 0.000 mean: 65.951 max: 278.058 nan: 0.00% (nan)
# [2025-09-10 11:45:13 INFO] variable SWnet_Wm2 min: 0.000 mean: 541.474 max: 929.140 nan: 0.00% (nan)
# [2025-09-10 11:45:13 INFO] variable LWin_Wm2 min: 173.045 mean: 343.019 max: 506.764 nan: 0.00% (nan)
# [2025-09-10 11:45:13 INFO] variable LWout_Wm2 min: 248.604 mean: 462.692 max: 693.334 nan: 0.00% (nan)
# [2025-09-10 11:45:13 INFO] variable Rn_Wm2 min: 0.000 mean: 421.883 max: 861.288 nan: 0.00% (nan)
# [2025-09-10 11:45:14 INFO] variable Rn_daylight_Wm2 min: 0.000 mean: 257.521 max: 452.982 nan: 0.00% (nan)
# [2025-09-10 11:45:14 INFO] Verma net radiation processing complete in 1.28 seconds
# [2025-09-10 11:45:14 INFO] completed forward process for perturbed input
# [2025-09-10 11:45:14 INFO] normalizing output perturbations
# [2025-09-10 11:45:14 INFO] Monte Carlo run complete
#   input_variable output_variable                  metric     value
# 0           ST_C          Rn_Wm2             correlation  0.023451
# 0           ST_C          Rn_Wm2                      r2  0.000550
# 0           ST_C          Rn_Wm2  mean_normalized_change  0.177906
# 0         albedo          Rn_Wm2             correlation  0.297327
# 0         albedo          Rn_Wm2                      r2  0.088403
# 0         albedo          Rn_Wm2  mean_normalized_change  0.063228
# 0           Ta_C          Rn_Wm2             correlation  0.008734
# 0           Ta_C          Rn_Wm2                      r2  0.000076
# 0           Ta_C          Rn_Wm2  mean_normalized_change  0.140327
# 0             RH          Rn_Wm2             correlation  0.126188
# 0             RH          Rn_Wm2                      r2  0.015924
# 0             RH          Rn_Wm2  mean_normalized_change  0.026822

# %% [markdown]
# ## Plot Sensitivity Magnitude Bar Chart
#
# This cell creates a bar chart showing the average percent change in latent heat flux for each input variable, visualizing the magnitude of model sensitivity to each input. The plot is saved as JPEG and SVG files with the BESS-JPL label.

# %%
df = sensitivity_metrics_df
df = df[(df.output_variable == "Rn_Wm2") & (df.metric == "mean_normalized_change")]
ax = sns.barplot(x=df.input_variable, y=df.value * 100, color='black')
ax.set_xticklabels(["Surface\nTemperature", "Albedo", "Air\nTemperature", "Relative\nHumidity"])
plt.xlabel("Input Variable")
plt.ylabel("Average Percent Change in Output Perturbation")
plt.title("Verma Net Radiation Sensitivity Magnitude")
# plt.ylim(0, 160)  # Set y-axis range from 0 to 160
plt.grid(axis='y', color='lightgray', linestyle='-', linewidth=0.5)  # Add light gray horizontal gridlines only

# Add percent sign to y-axis tick labels
ax.yaxis.set_major_formatter(FuncFormatter(lambda y, _: f'{int(y)}%'))

plt.savefig("Verma Net Radiation Sensitivity Magnitude.jpeg", format='jpeg', bbox_inches='tight')
plt.savefig("Verma Net Radiation Sensitivity Magnitude.svg", format='svg', bbox_inches='tight')

plt.show()
# Out:
# /var/folders/hk/35_x93nx79vg1zmd2fy1vcbr0000gq/T/ipykernel_75864/2658508637.py:4: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(["Surface\nTemperature", "Albedo", "Air\nTemperature", "Relative\nHumidity"])

# %% [markdown]
# ## Plot Sensitivity Correlation Bar Chart
#
# This cell generates a bar chart showing the correlation between input perturbations and output perturbations for each input variable, highlighting which inputs most strongly influence latent heat flux. The plot is saved as JPEG and SVG files with the PT-JPL-SM label.

# %%
df = sensitivity_metrics_df
df = df[(df.output_variable == "Rn_Wm2") & (df.metric == "correlation")]
ax = sns.barplot(x=df.input_variable, y=df.value, color='black')
ax.set_xticklabels(["Surface\nTemperature", "NDVI", "Albedo", "Air\nTemperature", "Relative\nHumidity"])
# plt.ylim(0, 0.8)
plt.xlabel("Input Variable")
plt.ylabel("Correlation of Input Perturbation to Output Perturbation")
plt.title("Verma Net Radiation Sensitivity Correlation")
plt.grid(axis='y')  # Add horizontal gridlines

plt.savefig("Verma Net Radiation Sensitivity Correlation.jpeg", format='jpeg', bbox_inches='tight')
plt.savefig("Verma Net Radiation Sensitivity Correlation.svg", format='svg', bbox_inches='tight')

plt.show()
# Out:
# /var/folders/hk/35_x93nx79vg1zmd2fy1vcbr0000gq/T/ipykernel_75864/778392315.py:4: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(["Surface\nTemperature", "NDVI", "Albedo", "Air\nTemperature", "Relative\nHumidity"])

# %% [markdown]
# ## Summary and Next Steps
#
# This notebook demonstrated a full sensitivity analysis workflow for the PT-JPL-SM model using ECOSTRESS Cal-Val data. Key results include the identification of input variables with the greatest influence on latent heat flux. Next steps could include further exploration of model parameters, additional visualizations, or application to other datasets.
